# %% [markdown]
# #SQL3 Lite

# %%
import sqlite3

# %%
connection = sqlite3.connect('example.db')
connection
cursor = connection.cursor()
# SQL3 Lite db will be created locally

# %%
# Create a Table

cursor.execute('''
    CREATE TABLE IF NOT EXISTS employees (
        id INTEGER PRIMARY KEY,
               name TEXT NOT NULL,
               age INTEGER,
               department TEXT
    )
''')

# Commit the changes
connection.commit()

# %%
cursor.execute('''
    SELECT * FROM employees
''')

# %%
# Insert Data into the Table

cursor.execute('''
    INSERT INTO employees (name, age, department)
               VALUES ('Sareen Garnaik', 29, 'HR'),
                ('John Doe', 34, 'Engineering'),
                ('Jane Smith', 28, 'Marketing')
''')
connection.commit()

# %%
# Query Data

cursor.execute('''
    SELECT * FROM employees
''') 


rows = cursor.fetchall()
print(rows)
# Out:
# [(1, 'Sareen Garnaik', 29, 'HR'), (2, 'John Doe', 34, 'Engineering'), (3, 'Jane Smith', 28, 'Marketing')]

# %%
# Update data in the table

cursor.execute('''
    UPDATE employees 
               SET age = 34 WHERE name = 'Sareen Garnaik'
''')

connection.commit()

cursor.execute('''
    SELECT * FROM employees
''')    
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Sareen Garnaik', 34, 'HR')
# (2, 'John Doe', 34, 'Engineering')
# (3, 'Jane Smith', 28, 'Marketing')

# %%
# Delete data from the table

cursor.execute('''  
    DELETE FROM employees WHERE name = 'John Doe'
''')

connection.commit()

cursor.execute('''
    SELECT * FROM employees
''')    
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Sareen Garnaik', 34, 'HR')
# (3, 'Jane Smith', 28, 'Marketing')

# %%
# Drop Table
# cursor.execute('''
#     DROP TABLE IF EXISTS employees
# ''')
connection.close()

# %% [markdown]
# > New Table Sales Order

# %%
connection = sqlite3.connect('Sales Order.db')
connection
cursor = connection.cursor()

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS sales (
               id INTEGER PRIMARY KEY,
               date TEXT NOT NULL,
               product TEXT NOT NULL,
               sales INTEGER,
               region TEXT
    )
               ''')

sales_data = [
    ('2023-01-15', 'Laptop', 1500, 'North'),
    ('2023-01-16', 'Smartphone', 800, 'South'),
    ('2023-01-17', 'Tablet', 600, 'East'),
    ('2023-01-18', 'Headphones', 200, 'West')
    ]

cursor.executemany('''
    INSERT INTO sales (date, product, sales, region)
                VALUES (?, ?, ?, ?)
                ''', sales_data)
connection.commit()

# %%
cursor.execute('''
    Select * FROM sales
               ''')

rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, '2023-01-15', 'Laptop', 1500, 'North')
# (2, '2023-01-16', 'Smartphone', 800, 'South')
# (3, '2023-01-17', 'Tablet', 600, 'East')
# (4, '2023-01-18', 'Headphones', 200, 'West')
