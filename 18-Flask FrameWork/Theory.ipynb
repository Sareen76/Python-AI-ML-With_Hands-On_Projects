# %% [markdown]
# ## Flask Framework

# %% [markdown]
# > We will make full application to use our model on , that's why we're using Flask

# %% [markdown]
# 1. WSAI - Web Server Gateway Interface
# 2. Jinja 2 Template Engine

# %% [markdown]
# Flask - Web Framework which is created with the Python Prog. Language. It's features are :

# %% [markdown]
# 1. Feature 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Feature 2 - Jinja 2 Template Engine
#
# Jinja 2 -> Web Template Engine
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
